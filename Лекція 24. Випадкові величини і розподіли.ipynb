# %% [markdown]
# ### Завдання 1. *Визначити ймовірність того, що його склав перший економіст*.
#
# - [x] Два економісти заповнюють документи з власними прогнозами щодо курсу певних коштовних паперів, після чого їх складають у спільну папку. Ймовірність відхилення прогнозованого значення курсу від фактичного понад допустиму похибку для 1-го економіста дорівнює 0,1, для 2-го - 0,2. 1-й економіст заповнив 40 документів, 2-й - 60 документів. Під час перевірки навмання взятий із папки документ виявився з суттєвою похибкою.
#    * Визначити ймовірність того, що його склав перший економіст.

# %% [markdown]
# $ P(Eco_1) $ - це подія 1 (для економіста 1). $ \\ $
# $ P(Eco_2) $ - це подія 2 (для економіста 2). $ \\ $
# $ А $ - намвання взятий із папки документ.

# %% [markdown]
# *Визначаю коефіцієнт для кожного економіста*: $ \\ $
# $ P(Eco_1) = \frac{40}{100} = 0,4 $ $ \\ $
# $ P(Eco_2) = \frac{60}{100} = 0,6 $

# %%
eco_1 = 40 / 100
print('𝐸𝑐𝑜_1 =', eco_1)

eco_2 = 60 / 100
print('𝐸𝑐𝑜_2 =', eco_2)
# Out:
# 𝐸𝑐𝑜_1 = 0.4
# 𝐸𝑐𝑜_2 = 0.6

# %% [markdown]
# $ P(A|Eco_1) = 0,1 $ (за умовою задачі похибка для 1-го економіста = 0,1) $ \\ $
# $ P(A|Eco_2) = 0,2 $ (за умовою задачі похибка для 2-го економіста = 0,2)

# %% [markdown]
# За *формулою повної ймовірності* визначемо коефіцієнт: $ \\ $
# $ P(A) = P(Eco_1)P(A|Eco_1) + P(Eco_2)P(A|Eco_2) = 0,4 ⋅ 0,1 + 0,6 ⋅ 0,2 = 0,16 $ $ \\ $
# Коефіцієнт = $ 0,16 $
#
# За *формулою Байєса* вирахуємо ймовірність заповнення документа із суттєвою похибкою першим економістом: $ \\ $
# $ P(Eco_1|A) = \frac{P(Eco_1)P(A|Eco_1)}{P(A)} = \frac{0,4 ⋅ 0,1}{0,16} = 0,25 $ $ \\ $
#
# **Отже, ймовірність для першого економіста $ P(Eco_1|A) $ становить** $ 0,25 $

# %%
p_a = 0.4 * 0.1 + 0.6 * 0.2
print('Коефіцієнт =', p_a)

p_eco_1 = 0.4 * 0.1 / 0.16
print('Ймовірність для першого економіста =', p_eco_1)
# Out:
# Коефіцієнт = 0.16
# Ймовірність для першого економіста = 0.25000000000000006

# %% [markdown]
# ### Завдання 2. *Оцінити ступінь ризику і запропонувати рішення щодо випуску і реалізації одного з наборів товарів*.
#
# - [x] Є можливість обрати спосіб виробництва і реалізації двох наборів товарів широкого вжитку. За даними відділу маркетингу, яким були проведені дослідження ринку, можливий прибуток від виробництва і реалізації X та Y наведено у таблицях (X, Y - прибуток у грошових одиницях) нижче.
#     * Оцінити ступінь ризику і запропонувати рішення щодо випуску і реалізації одного з наборів товарів.
# ---
#
# |*Таблиця 1*|  |      |       |
# |:---:  | :---:|:---: |:---:  |
# | **X** | 1000 | 1500 |  2000 |
# | **P** | 0,5  | 0,3  |  0,2  |
#
# ----
# |*Таблиця 2*|  |      |       |
# |:---:  | :---:|:---: |:---:  |
# | **Y** | 1000 | 1500 |  1750 |
# | **P** | 0,4  | 0,4  |  0,2  |
#
# ----

# %% [markdown]
# $ X, Y $ - випадкова величина.
#
# $ P $ - ймовірність випадкової величини.
#
# Cума всіх ймовірностей у таблицях 1 та 2 має дорівнювати $ P = 1 $, тобто 1:
#
# $ P(X) = 0,5 + 0,3 + 0,2 = 1 $ $ \\ $
# $ P(Y) = 0,4 + 0,4 + 0,2 = 1  $
#
# Отож умова для подальшого розрахунку є правильною.

# %% [markdown]
# $ M(X) $ - математичне сподівання.
#
# *Визначаю МАТЕМАТИЧНЕ СПОДІВАННЯ можливого прибутку для кожного з наборів товарів*:
#
# Відповідно до формули $ \sum^n _{i=1} X _i P_i $ :
#
# $ M(X) = 1000 ⋅ 0,5 + 1500 ⋅ 0,3 + 2000 ⋅ 0,2 = 1350 $ $ \\ $
# Відхилення від математичного сподівання для $ M(X) = X - M(X) = 1000 - 1350 = -350; 1500 - 1350 = 150; 2000 - 1350 = 650. $
#
# $ M(Y) = 1000 ⋅ 0,4 + 1500 ⋅ 0,4 + 1750 ⋅ 0,2 = 1350 $ $ \\ $
# Відхилення від математичного сподівання для $ M(Y) = Y - M(Y) = 1000 - 1350 = -350; 1500 - 1350 = 150; 1750 - 1350 = 400. $
#
# #### Для кожного набору товарів прибуток виявився однаковим: $ 1350 $

# %% [markdown]
# *Знаходжу ДИСПЕРСІЮ випакової величини та оцінюю ступінь ризику* ***першого набору***:
#
# $ D(X) = M(X^2) - (M(X)^2) = (1000 - 1350)^2 ⋅ 0,5 + (1500 - 1350)^2 ⋅ 0,3 + (2000 - 1350)^2 ⋅ 0,2 =
# \\ = 61250 + 6750 + 84 500 = 152500 $ $ \\ $
#
# ##### РИЗИК для першого набору з таблиці 1:
# $ σ(X) = \sqrt{D(X)} = \sqrt{152500} = 390,5 $

# %% [markdown]
# *Знаходжу ДИСПЕРСІЮ випакової величини та оцінюю ступінь ризику* ***другого набору***:
#
# $ D(Y) = M(Y^2) - (M(Y)^2) = (1000 - 1350)^2 ⋅ 0,4 + (1500 - 1350)^2 ⋅ 0,4 + (1750 - 1350)^2 ⋅ 0,2 =
# \\ = 49000 + 9000 + 32000 = 90000 $ $ \\ $
#
# ##### РИЗИК для другоо набору з таблиці 2:
# $ σ(Y) = \sqrt{D(Y)} = \sqrt{90000} = 300 $

# %% [markdown]
# ### Висновок
#
# Набір 1 з таблиці 1 з ризиком $ 390,5 $ більш ризикований у виробництві, ніж набір 2 з таблиці 2 з ризиком $ 300 $.
#
# **Реалізувати для виробнитва і продажу треба набір 2.**
